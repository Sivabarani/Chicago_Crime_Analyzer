# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\sivab\Personal\Study\Guvi\Chicago Crime

# %%
path = os.getcwd()

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# To read the File
file_path = path + '\\Crime_Data.csv'  
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#          ID Case Number              Date                      Block IUCR  \
# 0   5741943    HN549294    8/25/2007 9:22         074XX N ROGERS AVE  560
# 1     25953    JE240540   5/24/2021 15:06        020XX N LARAMIE AVE  110
# 2     26038    JE279849    6/26/2021 9:24      062XX N MC CORMICK RD  110
# 3  13279676    JG507211  11-09-2023 07:30           019XX W BYRON ST  620
# 4  13274752    JG501049  11-12-2023 07:59  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0                OTHER   False     False  ...  49.0             1.0       08A
# 1               STREET    True     False  ...  36.0            19.0       01A
# 2          PARKING LOT    True     False  ...  50.0            13.0       01A
# 3            APARTMENT   False     False  ...  47.0             5.0         5
# 4   SMALL RETAIL STORE    True     False  ...   6.0            44.0       08B
#
#    X Coordinate Y Coordinate  Year        Updated On   Latitude  Longitude  \
# 0           NaN          NaN  2007   8/17/2015 15:03        NaN        NaN
# 1     1141387.0    1913179.0  2021  11/18/2023 15:39  41.917838 -87.755969
# 2     1152781.0    1941458.0  2021  11/18/2023 15:39  41.995219 -87.713355
# 3     1162518.0    1925906.0  2023  11/18/2023 15:39  41.952345 -87.677975
# 4     1183071.0    1847869.0  2023  12-09-2023 15:41  41.737751 -87.604856
#
#                         Location
# 0                            NaN
# 1  (41.917838056, -87.755968972)
# 2  (41.995219444, -87.713354912)
# 3  (41.952345086, -87.677975059)
# 4  (41.737750767, -87.604855911)
#
# [5 rows x 22 columns]

# %%
# To check the column names
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
# To check the data types
print("Total length ", len(df))
df.info()
# Out:
# Total length  549999
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  object
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
#  14  FBI Code              549999 non-null  object
#  15  X Coordinate          543087 non-null  float64
#  16  Y Coordinate          543087 non-null  float64
#  17  Year                  549999 non-null  int64
#  18  Updated On            549999 non-null  object
#  19  Latitude              543087 non-null  float64
#  20  Longitude             543087 non-null  float64
#  21  Location              543087 non-null  object
# dtypes: bool(2), float64(6), int64(4), object(10)
# memory usage: 85.0+ MB

# %%
# To check , if duplicate value is exist
# The ouptut is zero. From this output, we can determine, there is no duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# To check the null values
df.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      1673
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    336325
# Community Area          334906
# FBI Code                     0
# X Coordinate              6912
# Y Coordinate              6912
# Year                         0
# Updated On                   0
# Latitude                  6912
# Longitude                 6912
# Location                  6912
# dtype: int64

# %%
for i in df.select_dtypes(include="object").columns:
    print(f"unique values of {i} = {df[i].nunique()}")
# Out:
# unique values of Case Number = 549434
# unique values of Date = 244168
# unique values of Block = 51020
# unique values of IUCR = 356
# unique values of Primary Type = 34
# unique values of Description = 449
# unique values of Location Description = 210
# unique values of FBI Code = 27
# unique values of Updated On = 2272
# unique values of Location = 278640

# %%
# find the unique values in prmary type
df['Primary Type'].unique()
# Out:
# array(['ASSAULT', 'HOMICIDE', 'BURGLARY', 'BATTERY', 'THEFT',
#        'CRIMINAL DAMAGE', 'DECEPTIVE PRACTICE', 'CRIMINAL SEXUAL ASSAULT',
#        'OFFENSE INVOLVING CHILDREN', 'MOTOR VEHICLE THEFT', 'ROBBERY',
#        'SEX OFFENSE', 'OTHER OFFENSE', 'WEAPONS VIOLATION', 'STALKING',
#        'CRIMINAL TRESPASS', 'PROSTITUTION', 'ARSON', 'NARCOTICS',
#        'KIDNAPPING', 'CONCEALED CARRY LICENSE VIOLATION',
#        'INTERFERENCE WITH PUBLIC OFFICER', 'PUBLIC PEACE VIOLATION',
#        'OBSCENITY', 'LIQUOR LAW VIOLATION', 'INTIMIDATION',
#        'HUMAN TRAFFICKING', 'GAMBLING', 'CRIM SEXUAL ASSAULT',
#        'OTHER NARCOTIC VIOLATION', 'NON-CRIMINAL', 'PUBLIC INDECENCY',
#        'RITUALISM', 'DOMESTIC VIOLENCE'], dtype=object)

# %%
# Modify the 'Primary Type' column to update specific values for consistency
df['Primary Type'] = df['Primary Type'].apply(lambda i: 'CRIMINAL SEXUAL ASSAULT' if i == 'CRIM SEXUAL ASSAULT' else i)

# %%
# To find the unique value in Description
df['Description'].unique()
# Out:
# array(['SIMPLE', 'FIRST DEGREE MURDER', 'UNLAWFUL ENTRY',
#        'AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY',
#        '$500 AND UNDER', 'TO VEHICLE',
#        'FINANCIAL IDENTITY THEFT OVER $ 300', 'NON-AGGRAVATED',
#        'TO PROPERTY', 'OVER $500', 'FORGERY', 'FROM BUILDING',
#        'BOGUS CHECK', 'CHILD ABDUCTION', 'AUTOMOBILE',
#        'ATTEMPT - FINANCIAL IDENTITY THEFT', 'ARMED - HANDGUN',
#        'PREDATORY', 'VEHICULAR HIJACKING',
#        'SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
#        'INDECENT SOLICITATION OF A CHILD',
#        'HARASSMENT BY ELECTRONIC MEANS',
#        'AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
#        'SEXUAL EXPLOITATION OF A CHILD',
#        'AGGRAVATED CRIMINAL SEXUAL ABUSE', 'RECKLESS FIREARM DISCHARGE',
#        'CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
#        'DOMESTIC BATTERY SIMPLE',
#        'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
#        'CYBERSTALKING', 'AGGRAVATED - OTHER', 'RETAIL THEFT',
#        'TO STATE SUP LAND', 'THEFT OF LOST / MISLAID PROPERTY', 'TO LAND',
#        'ATTEMPT - AUTOMOBILE',
#        'AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON',
#        'OTHER VEHICLE OFFENSE', 'FALSE / STOLEN / ALTERED TRP',
#        'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#        'VEHICLE TITLE / REGISTRATION OFFENSE', 'AGGRAVATED - HANDGUN',
#        'STRONG ARM - NO WEAPON', 'SOLICITING FOR BUSINESS',
#        'ILLEGAL USE CASH CARD', 'BY FIRE', 'TO STATE SUPPORTED PROPERTY',
#        'TELEPHONE THREAT', 'ATTEMPT FORCIBLE ENTRY', 'FORCIBLE ENTRY',
#        'VIOLATE ORDER OF PROTECTION', 'POSSESS - CRACK', 'TO RESIDENCE',
#        'THEFT / RECOVERY - AUTOMOBILE',
#        'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'ENDANGERING LIFE / HEALTH OF CHILD', 'UNLAWFUL RESTRAINT',
#        'AGGRAVATED', 'ARMED - OTHER FIREARM',
#        'ARMED - OTHER DANGEROUS WEAPON', 'CRIMINAL SEXUAL ABUSE',
#        'FRAUD OR CONFIDENCE GAME', 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#        'PROHIBITED PLACES', 'OTHER OFFENSE',
#        'UNLAWFUL POSSESSION - HANDGUN', 'COUNTERFEITING DOCUMENT',
#        'TO CITY OF CHICAGO PROPERTY', 'THEFT OF LABOR / SERVICES',
#        'POSSESS - HEROIN (WHITE)', 'CREDIT CARD FRAUD',
#        'RESIST / OBSTRUCT / DISARM OFFICER',
#        'AGGRAVATED VEHICULAR HIJACKING',
#        'NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES',
#        'THEFT BY LESSEE, MOTOR VEHICLE', 'BOMB THREAT',
#        'FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON',
#        'AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'OTHER VIOLATION', 'CYCLE, SCOOTER, BIKE WITH VIN', 'CHILD ABUSE',
#        'POSSESS - HEROIN (BLACK TAR)', 'ATTEMPT ARMED - HANDGUN',
#        'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#        'POCKET-PICKING', 'UNLAWFUL USE - OTHER FIREARM',
#        'AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'POSSESS - BARBITURATES', 'OTHER CRIME AGAINST PERSON',
#        'ATTEMPT AGGRAVATED', 'HOME INVASION',
#        'ILLEGAL POSSESSION CASH CARD', 'LICENSE VIOLATION',
#        'STOLEN PROPERTY BUY / RECEIVE / POSSESS',
#        'HARASSMENT BY TELEPHONE', 'POSSESS - CANNABIS MORE THAN 30 GRAMS',
#        'FINANCIAL IDENTITY THEFT $300 AND UNDER',
#        'ATTEMPT - CYCLE, SCOOTER, BIKE WITH VIN',
#        'SOLICIT NARCOTICS ON PUBLIC WAY', 'COMPUTER FRAUD',
#        'POSSESS - COCAINE', 'POSSESS - SYNTHETIC DRUGS',
#        'VIOLATION OF STALKING NO CONTACT ORDER',
#        'AGGRAVATED FINANCIAL IDENTITY THEFT',
#        'UNLAWFUL USE - OTHER DANGEROUS WEAPON',
#        'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS',
#        'AGGRAVATED OF A SENIOR CITIZEN', 'EMBEZZLEMENT',
#        'CHILD PORNOGRAPHY', 'ATTEMPT THEFT', 'COUNTERFEIT CHECK', 'OTHER',
#        'PUBLIC INDECENCY',
#        'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT',
#        'GUN OFFENDER - ANNUAL REGISTRATION', 'FALSE POLICE REPORT',
#        'FOUND SUSPECT NARCOTICS',
#        'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON',
#        'AGGRAVATED DOMESTIC BATTERY - HANDGUN',
#        'AGGRAVATED - OTHER FIREARM', 'OBSTRUCTING SERVICE',
#        'GUN OFFENDER - DUTY TO REGISTER',
#        'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY',
#        'ATTEMPT ARSON', 'CRIMINAL DEFACEMENT',
#        'POSSESSION OF BURGLARY TOOLS',
#        'ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT', 'RECKLESS CONDUCT',
#        'PURSE-SNATCHING', 'VIOLATION GPS MONITORING DEVICE',
#        'AGGRAVATED OF A CHILD', 'POSSESS - CANNABIS 30 GRAMS OR LESS',
#        'ANIMAL ABUSE / NEGLECT', 'OBSCENE TELEPHONE CALLS',
#        'ATTEMPT STRONG ARM - NO WEAPON',
#        'THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN',
#        'AGGRAVATED POLICE OFFICER - HANDGUN',
#        'OTHER CRIME INVOLVING PROPERTY', 'KIDNAPPING',
#        'OBSTRUCTING JUSTICE',
#        'SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR', 'EMPLOY MINOR',
#        'ARMED - KNIFE / CUTTING INSTRUMENT',
#        'POSSESSION OF DRUG EQUIPMENT',
#        'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY',
#        'OF AN UNBORN CHILD', 'SELL / GIVE / DELIVER LIQUOR TO MINOR',
#        'INTIMIDATION', 'POSSESS - HALLUCINOGENS', 'POSSESS - PCP',
#        'CHILD ABDUCTION / STRANGER', 'DECEPTIVE COLLECTION PRACTICES',
#        'UNLAWFUL POSSESSION - AMMUNITION', 'UNLAWFUL USE - HANDGUN',
#        'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
#        'AGGRAVATED COMPUTER TAMPERING',
#        'CONTRIBUTE TO THE DELINQUENCY OF CHILD', 'TRUCK, BUS, MOTOR HOME',
#        'ARMED: HANDGUN',
#        'AGGRAVATED P.O. - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'SEX OFFENDER - FAIL TO REGISTER', 'INVOLUNTARY SERVITUDE',
#        'VIOLATION OF CIVIL NO CONTACT ORDER', 'GAME/DICE',
#        'OBSTRUCTING IDENTIFICATION', 'ATTEMPT NON-AGGRAVATED',
#        'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT',
#        'UNAUTHORIZED VIDEOTAPING',
#        'MANUFACTURE / DELIVER -  HEROIN (WHITE)',
#        'LIQUOR LICENSE VIOLATION', 'SOLICIT ON PUBLIC WAY',
#        'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
#        'CYCLE, SCOOTER, BIKE NO VIN',
#        'VIOLENT OFFENDER - DUTY TO REGISTER',
#        'UNLAWFUL USE OF A COMPUTER', 'CHILD ABANDONMENT',
#        'POSSESS - METHAMPHETAMINE', 'ESCAPE', 'ARMED VIOLENCE',
#        'OBSCENE MATTER', 'SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS',
#        'ATTEMPT ARMED - OTHER DANGEROUS WEAPON', 'EXTORTION',
#        'POSS: COCAINE', 'UNLAWFUL SALE - HANDGUN',
#        'OTHER WEAPONS VIOLATION', 'MANUFACTURE / DELIVER - CRACK',
#        'MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS',
#        'AGGRAVATED PROTECTED EMPLOYEE - HANDGUN', 'IMPERSONATION',
#        'POSS: HEROIN(WHITE)', 'POSS: CRACK',
#        'THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME',
#        'POSSESS - HEROIN (TAN / BROWN TAR)',
#        'UNLAWFUL VISITATION INTERFERENCE', 'FORFEIT PROPERTY',
#        'ALTER / FORGE PRESCRIPTION', 'SOLICIT OFF PUBLIC WAY',
#        'POSSESS FIREARM / AMMUNITION - NO FOID CARD',
#        'THEFT BY LESSEE, NON-MOTOR VEHICLE', 'DELIVERY CONTAINER THEFT',
#        'ATTEMPT AGGRAVATED - OTHER', 'ARSON THREAT',
#        'GUN OFFENDER - DUTY TO REPORT CHANGE OF INFORMATION',
#        'TAMPER WITH MOTOR VEHICLE', 'UNLAWFUL POSSESSION - OTHER FIREARM',
#        'MANUFACTURE / DELIVER - METHAMPHETAMINE', 'TO AIRPORT',
#        'PEEPING TOM', 'ARMED WHILE UNDER THE INFLUENCE',
#        'ATTEMPT ARMED - OTHER FIREARM',
#        'TIRE DEFLATION DEVICE DEPLOYMENT', 'PAROLE VIOLATION',
#        'AGGRAVATED: HANDGUN', 'UNLAWFUL USE / SALE OF AIR RIFLE',
#        'POSSESSION OF PORNOGRAPHIC PRINT',
#        'VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE',
#        'BOARD PLANE WITH WEAPON', 'POSSESS - AMPHETAMINES',
#        'CRIMINAL DRUG CONSPIRACY',
#        'THEFT / RECOVERY - CYCLE, SCOOTER, BIKE NO VIN',
#        'SEX OFFENDER - PROHIBITED ZONE', 'ATTEMPT CRIMINAL SEXUAL ABUSE',
#        'SEXUAL RELATIONS IN FAMILY', 'INSURANCE FRAUD',
#        'INSTITUTIONAL VANDALISM',
#        'MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR)',
#        'STRONGARM - NO WEAPON', 'ATTEMPT - TRUCK, BUS, MOTOR HOME',
#        'HAZARDOUS MATERIALS VIOLATION', 'ATTEMPT AGGRAVATED - HANDGUN',
#        'ABUSE / NEGLECT - CARE FACILITY', 'MANU/DELIVER:CRACK',
#        'MOB ACTION', 'OBSCENITY', 'MANUFACTURE / DELIVER - COCAINE',
#        'RECKLESS HOMICIDE', 'COMMERCIAL SEX ACTS', 'FORCIBLE DETENTION',
#        'ATT: AUTOMOBILE', '$300 AND UNDER',
#        'MANUFACTURE / DELIVER - BARBITURATES',
#        'MANUFACTURE / DELIVER - SYNTHETIC DRUGS', 'EAVESDROPPING',
#        'ATTEMPT - CYCLE, SCOOTER, BIKE NO VIN',
#        'OTHER ARSON / EXPLOSIVE INCIDENT', 'PUBLIC DEMONSTRATION',
#        'INTERFERENCE JUDICIAL PROCESS', 'BIGAMY',
#        'ILLEGAL POSSESSION BY MINOR',
#        'AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM',
#        'VIOLENT OFFENDER - FAIL TO REGISTER NEW ADDRESS',
#        'MANUFACTURE / DELIVER - AMPHETAMINES',
#        'VIOLENT OFFENDER - ANNUAL REGISTRATION',
#        'OTHER PROSTITUTION OFFENSE',
#        'ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#        'MANUFACTURE / DELIVER - HALLUCINOGEN', 'BRIBERY',
#        'INTOXICATING COMPOUNDS', 'VIOLATION OF SMOKING BAN',
#        'SALE / DELIVER - DRUG PARAPHERNALIA',
#        'CONCEALED CARRY LICENSE REVOCATION', 'FORNICATION',
#        'AGG: FINANCIAL ID THEFT', 'PAY TV SERVICE OFFENSES',
#        'LICENSED PREMISE', 'AGGRAVATED POLICE OFFICER - OTHER FIREARM',
#        'FALSE FIRE ALARM', 'POSSESSION - EXPLOSIVE / INCENDIARY DEVICE',
#        'FROM COIN-OPERATED MACHINE OR DEVICE',
#        'AGGRAVATED OF AN UNBORN CHILD', 'ARSONIST - ANNUAL REGISTRATION',
#        'ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE',
#        'AGG CRIM SEX ABUSE FAM MEMBER', 'MANU/DELIVER: HEROIN (WHITE)',
#        'INTERFERE WITH EMERGENCY EQUIPMENT',
#        'CRIM SEX ABUSE BY FAM MEMBER', 'AGG CRIMINAL SEXUAL ABUSE',
#        'POSS: CANNABIS MORE THAN 30GMS', 'POSSESS - LOOK-ALIKE DRUGS',
#        'SEX ASSLT OF CHILD BY FAM MBR', 'HARBOR RUNAWAY',
#        'AGG SEX ASSLT OF CHILD FAM MBR',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
#        'FINAN EXPLOIT-ELDERLY/DISABLED', 'ATT CRIM SEXUAL ABUSE',
#        'AGGRAVATED: OTHER',
#        'CONTRIBUTE TO THE CRIMINAL DELINQUENCY OF CHILD',
#        'MANUFACTURE / DELIVER - SYNTHETIC MARIJUANA',
#        'MANU/DEL:CANNABIS 10GM OR LESS', 'POSS: HALLUCINOGENS',
#        'THEFT/RECOVERY: AUTOMOBILE', 'INDECENT SOLICITATION/CHILD',
#        'INTIMIDATION OF LAW ENFORCEMENT OFFICIAL',
#        'DELIVER CANNABIS TO PERSON UNDER 18',
#        'INDECENT SOLICITATION OF AN ADULT', 'MANUFACTURE / DELIVER - PCP',
#        'CANNABIS PLANT', 'CRIMINAL TRANSMISSION OF HIV',
#        'UNLAWFUL SALE - DELIVERY OF FIREARM AT SCHOOL',
#        'ATTEMPT POSSESSION NARCOTICS',
#        'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY',
#        'ILLEGAL CONSUMPTION BY MINOR',
#        'ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON',
#        'ALTER/FORGE PRESCRIPTION', 'FALSE/STOLEN/ALTERED TRP',
#        'BY EXPLOSIVE',
#        'FAILURE TO MAINTAIN RECORDS - CONTROLLED SUBSTANCES',
#        'ATTEMPT POSSESSION CANNABIS', 'POSSESSION - SYNTHETIC MARIJUANA',
#        'AGGRAVATED: OTHER DANG WEAPON', 'POSS: CANNABIS 30GMS OR LESS',
#        'ADULTRY', 'OFFICIAL MISCONDUCT',
#        'ATTEMPT AGGRAVATED - OTHER FIREARM',
#        'SEX OFFENDER: FAIL REG NEW ADD',
#        'MANUFACTURE / DELIVER - LOOK-ALIKE DRUG',
#        'THEFT OF LABOR/SERVICES',
#        'AGGRAVATED DOMESTIC BATTERY - OTHER FIREARM',
#        'INVOLUNTARY MANSLAUGHTER',
#        'DEFACE IDENTIFICATION MARKS OF FIREARM', 'MONEY LAUNDERING',
#        'LOOTING', 'AGG: HANDS/FIST/FEET NO/MINOR INJURY',
#        'AGGRAVATED:KNIFE/CUTTING INSTR', 'ENDANGERING LIFE/HEALTH CHILD',
#        'VIO BAIL BOND: DOM VIOLENCE', 'AGGRAVATED DOMESTIC BATTERY',
#        'TO STATE SUP PROP', 'FINANCIAL ID THEFT:$300 &UNDER',
#        'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST',
#        'FINANCIAL ID THEFT: OVER $300',
#        'FINANCIAL IDENTITY THEFT: $300 & UNDER',
#        'NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES',
#        'ATTEMPT: STRONGARM-NO WEAPON', 'ATTEMPT: ARMED-HANDGUN',
#        'AGGRAVATED: OTHER FIREARM', 'POSS: SYNTHETIC DRUGS',
#        'CHILD ABDUCTION/STRANGER', 'POSS: HEROIN(BRN/TAN)',
#        'AGG PO HANDS NO/MIN INJURY', 'ATTEMPT: AGGRAVATED',
#        'SOLICIT FOR BUSINESS', 'ARMED:KNIFE/CUTTING INSTRUMENT',
#        'CALL OPERATION', 'SOLICIT NARCOTICS ON PUBLICWAY',
#        'UNLAWFUL POSS OF HANDGUN', 'UNLAWFUL USE OTHER DANG WEAPON',
#        'THEFT BY LESSEE,NON-VEH', 'MANU/DEL:CANNABIS OVER 10 GMS',
#        'UNLAWFUL POSS AMMUNITION', 'SEX OFFENDER: FAIL TO REGISTER',
#        'THEFT OF LOST/MISLAID PROP', 'UNLAWFUL INTERFERE/VISITATION',
#        'THEFT BY LESSEE,MOTOR VEH', 'ARMED: OTHER DANGEROUS WEAPON',
#        'SELL/GIVE/DEL LIQUOR TO MINOR', 'SALE/DEL HYPODERMIC NEEDLE',
#        'AGGRAVATED: KNIFE/CUT INSTR', 'AGG RITUAL MUT:KNIFE/CUTTING I',
#        'AGG PRO.EMP:KNIFE/CUTTING INST', 'ATT: TRUCK, BUS, MOTOR HOME',
#        'ATTEMPT: ARMED-KNIFE/CUT INSTR', 'CYCLE, SCOOTER, BIKE W-VIN',
#        'STOLEN PROP: BUY/RECEIVE/POS.', 'MANU/DELIVER:PCP',
#        'UNLAWFUL POSS OTHER FIREARM', 'THEFT/RECOVERY: TRUCK,BUS,MHOME',
#        'POSS: PCP', 'ATTEMPT: ARMED-OTHER DANG WEAP',
#        'GAME/AMUSEMENT DEVICE', 'ATTEMPT: ARMED-OTHER FIREARM',
#        'MANU/DELIVER:LOOK-ALIKE DRUG', 'UNLAWFUL USE HANDGUN',
#        'POS: HYPODERMIC NEEDLE', 'AGG PRO.EMP: HANDGUN',
#        'UNLAWFUL USE/SALE AIR RIFLE', 'UNLAWFUL USE OTHER FIREARM',
#        'ATTEMPT AGG: KNIFE/CUT INSTR', 'PRO EMP HANDS NO/MIN INJURY',
#        'CONTRIBUTE DELINQUENCY OF A CHILD', 'AGGRAVATED PO: HANDGUN',
#        'ARMED: OTHER FIREARM', 'RESIST/OBSTRUCT/DISARM OFFICER',
#        'UNLAWFUL USE OF RECORDED SOUND', 'ATTEMPT AGG: OTHER DANG WEAPON',
#        'UNLAWFUL SALE HANDGUN', 'AGGRAVATED PO: KNIFE/CUT INSTR',
#        'MANU/DELIVER:COCAINE', 'ATT AGG CRIMINAL SEXUAL ABUSE',
#        'AGG RITUAL MUT:OTH DANG WEAPON', 'PATRONIZING A PROSTITUTE',
#        'WIREROOM/SPORTS', 'POSS FIREARM/AMMO:NO FOID CARD', 'GAME/CARDS',
#        'AGGRAVATED PO: OTHER DANG WEAP', 'MANU/DELIVER:HEROIN(BLACK TAR)',
#        'POSS: AMPHETAMINES', 'CAB OPERATION',
#        'MANU/DELIVER: HALLUCINOGEN', 'POSS: BARBITUATES',
#        'POSS: HEROIN(BLACK TAR)', 'TO FIRE FIGHT.APP.EQUIP',
#        'POSS: LOOK-ALIKE DRUGS', 'MANU/DELIVER: HEROIN(BRN/TAN)',
#        'VIOL CHARITABLE GAME ACT', 'AGGRAVATED PO: OTHER FIREARM',
#        'DELIVER CANNABIS TO PERSON <18', 'MANU/DELIVER:AMPHETAMINES',
#        'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN',
#        'MANU/DELIVER:BARBITUATES', 'INDECENT SOLICITATION/ADULT',
#        'AGGRAVATED PO:KNIFE/CUT INSTR', 'BOOKMAKING/SPORTS',
#        'UNLAWFUL SALE OTHER FIREARM', 'DOMESTIC VIOLENCE',
#        'REGISTER OF SALES BY DEALER', 'AGG PRO.EMP: OTHER DANG WEAPON',
#        'ILLEGAL ILL LOTTERY', 'ATTEMPT AGG: HANDGUN',
#        'SOLICIT FOR PROSTITUTE', 'MANU/DELIVER:SYNTHETIC DRUGS',
#        'ATTEMPT AGG: OTHER', 'PIMPING', 'MINOR MISREPRESENT AGE',
#        'IN TAVERN', 'PANDERING', 'POS: EXPLOSIVE/INCENDIARY DEV',
#        'LOTTERY/OTHER', 'OTHER ARSON/EXPLOSIVE INCIDENT',
#        'ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN', 'BOOKMAKING/HORSES',
#        'OVER $300', 'KEEP PLACE OF PROSTITUTION',
#        'SALE/DIST OBSCENE MAT TO MINOR',
#        'FINANCIAL IDENTITY THEFT: OVER $300',
#        'POSS. KEYS OR DEV.TO COIN MACH', 'WIREROOM/HORSES',
#        'ATT AGG CRIM SEXUAL ABUSE', 'DEFACE IDENT MARKS OF FIREARM',
#        'POLICY/OTHER', 'REFUSING TO AID AN OFFICER',
#        'DEL CONT SUBS TO PERSON <18', 'CONCEALING/AIDING A FUGITIVE',
#        'SEX RELATION IN FAMILY', 'AGG RITUAL MUT:HANDGUN',
#        'SEX OFFENDER: PROHIBITED ZONE', 'BOLITA OR BOLI PUL/WRITER',
#        'BOLITA OR BOLI PUL/RUNNER'], dtype=object)

# %%
# Modify the 'Description' column to update specific values for consistency
replacements = {
    "AGGRAVATED:KNIFE/CUTTING INSTR" : "AGGRAVATED - KNIFE / CUTTING INSTRUMENT",
    "AGGRAVATED: KNIFE/CUT INSTR" :  "AGGRAVATED - KNIFE / CUTTING INSTRUMENT",
    "ARMED:KNIFE/CUTTING INSTRUMENT" : "ARMED - KNIFE / CUTTING INSTRUMENT",
    "ATTEMPT: ARMED-KNIFE/CUT INSTR" : "ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT",
    "AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST" : "AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT",
    "AGG PRO.EMP:KNIFE/CUTTING INST" : "AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT",
    "AGGRAVATED PO: KNIFE/CUT INSTR" : "AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT",
    "AGGRAVATED PO:KNIFE/CUT INSTR" : "AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT",
    "ATTEMPT AGG: KNIFE/CUT INSTR" : "ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT",
    "NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES" : "NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES",
    "SEX OFFENDER: FAIL TO REGISTER" : "SEX OFFENDER - FAIL TO REGISTER",
    "SEX OFFENDER: FAIL REG NEW ADD" : "SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS",
    "AGG CRIMINAL SEXUAL ABUSE" : "AGGRAVATED CRIMINAL SEXUAL ABUSE",
    "CRIM SEX ABUSE BY FAM MEMBER" : "CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER",
    "SEX OFFENDER: PROHIBITED ZONE" : "SEX OFFENDER - PROHIBITED ZONE",
    "SEX RELATION IN FAMILY" : "SEXUAL RELATIONS IN FAMILY",
    "ATT AGG CRIM SEXUAL ABUSE" : "ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE",
    "ATT AGG CRIMINAL SEXUAL ABUSE" : "ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE",
    "ATT CRIM SEXUAL ABUSE" : "ATTEMPT CRIMINAL SEXUAL ABUSE",
    "AGG CRIM SEX ABUSE FAM MEMBER" : "AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER",
    "AGG SEX ASSLT OF CHILD FAM MBR" : "AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER",
    "SEX ASSLT OF CHILD BY FAM MBR" : "SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER",
    "ATTEMPT AGG: OTHER DANG WEAPON" : "ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON",
    "AGGRAVATED: OTHER DANG WEAPON" : "AGGRAVATED - OTHER DANGEROUS WEAPON",
    "AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON" : "AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON",
    "AGGRAVATED PO: OTHER DANG WEAP" : "AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON",
    "AGG PRO.EMP: OTHER DANG WEAPON" : "AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON",
    "ARMED: OTHER DANGEROUS WEAPON" : "ARMED - OTHER DANGEROUS WEAPON",
    "ENDANGERING LIFE/HEALTH CHILD" : "ENDANGERING LIFE / HEALTH OF CHILD",
    "UNLAWFUL USE OTHER DANG WEAPON" : "UNLAWFUL USE - OTHER DANGEROUS WEAPON",
    "ATTEMPT: ARMED-OTHER DANG WEAP" : "ATTEMPT ARMED - OTHER DANGEROUS WEAPON",
    "PRO EMP HANDS NO/MIN INJURY" : "PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY",
    "AGG: HANDS/FIST/FEET NO/MINOR INJURY" : "AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY",
    "AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY" : "AGGRAVATED DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY",
    "UNLAWFUL SALE HANDGUN" : "UNLAWFUL SALE - HANDGUN",
    "ARMED: HANDGUN" : "ARMED - HANDGUN",
    "UNLAWFUL USE HANDGUN" : "UNLAWFUL USE - HANDGUN",
    "AGGRAVATED PO: HANDGUN" : "AGGRAVATED POLICE OFFICER - HANDGUN",
    "AGG PRO.EMP: HANDGUN" : "AGGRAVATED PROTECTED EMPLOYEE - HANDGUN",
    "UNLAWFUL POSS OF HANDGUN" : "UNLAWFUL POSSESSION - HANDGUN",
    "ATTEMPT AGG: HANDGUN" : "ATTEMPT AGGRAVATED - HANDGUN",
    "AGGRAVATED: HANDGUN" : "AGGRAVATED - HANDGUN",
    "ATTEMPT: ARMED-HANDGUN" : "ATTEMPT ARMED - HANDGUN",
    "ARMED: OTHER FIREARM" : "ARMED - OTHER FIREARM",
    "ATTEMPT: ARMED-OTHER FIREARM" : "ATTEMPT ARMED - OTHER FIREARM",
    "UNLAWFUL POSS OTHER FIREARM" : "UNLAWFUL POSSESSION - OTHER FIREARM",
    "UNLAWFUL USE OTHER FIREARM" : "UNLAWFUL USE - OTHER FIREARM",
    "AGGRAVATED: OTHER FIREARM" : "AGGRAVATED - OTHER FIREARM",
    "DEFACE IDENT MARKS OF FIREARM" : "DEFACE IDENTIFICATION MARKS OF FIREARM",
    "AGGRAVATED PO: OTHER FIREARM" : "AGGRAVATED POLICE OFFICER - OTHER FIREARM",
    "POSS FIREARM/AMMO:NO FOID CARD" : "POSSESS FIREARM / AMMUNITION - NO FOID CARD",
    "MANU/DELIVER: HEROIN (WHITE)" : "MANUFACTURE / DELIVER -  HEROIN (WHITE)",
    "POSS: HEROIN(WHITE)" : "POSSESS - HEROIN (WHITE)",
    "MANU/DELIVER: HEROIN(BRN/TAN)" : "MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR)",
    "POSS: HEROIN(BLACK TAR)" : "POSSESS - HEROIN (BLACK TAR)",
    "POSS: HEROIN(BRN/TAN)" : "POSSESS - HEROIN (TAN / BROWN TAR)",
    "MANU/DEL:CANNABIS OVER 10 GMS" : "MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS",
    "MANU/DELIVER:CRACK" : "MANUFACTURE / DELIVER - CRACK",
    "MANU/DELIVER:COCAINE" : "MANUFACTURE / DELIVER - COCAINE",
    "MANU/DELIVER:PCP" : "MANUFACTURE / DELIVER - PCP",
    "MANU/DELIVER: HALLUCINOGEN" : "MANUFACTURE / DELIVER - HALLUCINOGEN",
    "MANU/DELIVER:SYNTHETIC DRUGS" : "MANUFACTURE / DELIVER - SYNTHETIC DRUGS",
    "MANU/DELIVER:BARBITUATES" : "MANUFACTURE / DELIVER - BARBITURATES",
    "MANU/DELIVER:AMPHETAMINES" : "MANUFACTURE / DELIVER - AMPHETAMINES",
    "MANU/DELIVER:LOOK-ALIKE DRUG" : "MANUFACTURE / DELIVER - LOOK-ALIKE DRUG",
    "MANU/DEL:CANNABIS 10GM OR LESS" : "MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS",
    "ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN" : "ATTEMPT - CYCLE, SCOOTER, BIKE WITH VIN",
    "THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN" : "THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN",
    "UNLAWFUL POSS AMMUNITION" : "UNLAWFUL POSSESSION - AMMUNITION",
    "UNLAWFUL USE/SALE AIR RIFLE" : "UNLAWFUL USE / SALE OF AIR RIFLE",
    "POSS: CANNABIS MORE THAN 30GMS" : "POSSESS - CANNABIS MORE THAN 30 GRAMS",
    "POSS: CANNABIS 30GMS OR LESS" : "POSSESS - CANNABIS 30 GRAMS OR LESS",
    "POSS: SYNTHETIC DRUGS" : "POSSESS - SYNTHETIC DRUGS",
    "POSS: AMPHETAMINES" : "POSSESS - AMPHETAMINES",
    "POSS: LOOK-ALIKE DRUGS" : "POSSESS - LOOK-ALIKE DRUGS",
    "POSS: PCP" : "POSSESS - PCP",
    "POSS: CRACK" : "POSSESS - CRACK",
    "POSS: HALLUCINOGENS" : "POSSESS - HALLUCINOGENS",
    "POSS: COCAINE" : "POSSESS - COCAINE",
    "POSS: BARBITUATES" : "POSSESS - BARBITURATES",
    "SALE/DIST OBSCENE MAT TO MINOR" : "SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR",
    "ATTEMPT: AGGRAVATED" : "ATTEMPT AGGRAVATED",
    "AGGRAVATED: OTHER" : "AGGRAVATED - OTHER",
    "AGG: FINANCIAL ID THEFT" : "AGGRAVATED FINANCIAL IDENTITY THEFT",
    "ATTEMPT AGG: OTHER" : "ATTEMPT AGGRAVATED - OTHER",
    "ATTEMPT: STRONGARM-NO WEAPON" : "ATTEMPT STRONG ARM - NO WEAPON",
    "ATT: TRUCK, BUS, MOTOR HOME" : "ATTEMPT - TRUCK, BUS, MOTOR HOME",
    "ATT: AUTOMOBILE" : "ATTEMPT - AUTOMOBILE",
    "THEFT/RECOVERY: AUTOMOBILE" : "THEFT / RECOVERY - AUTOMOBILE",
    "THEFT OF LABOR/SERVICES" : "THEFT OF LABOR / SERVICES",
    "THEFT OF LOST/MISLAID PROP" : "THEFT OF LOST / MISLAID PROPERTY",
    "THEFT BY LESSEE,NON-VEH" : "THEFT BY LESSEE, NON-MOTOR VEHICLE",
    "THEFT BY LESSEE,MOTOR VEH" : "THEFT BY LESSEE, MOTOR VEHICLE",
    "THEFT/RECOVERY: TRUCK,BUS,MHOME" : "THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME",
    "FINANCIAL IDENTITY THEFT: OVER $300" : "FINANCIAL IDENTITY THEFT OVER $ 300",
    "FINANCIAL ID THEFT: OVER $300" : "FINANCIAL IDENTITY THEFT OVER $ 300",
    "FINANCIAL IDENTITY THEFT: $300 & UNDER" : "FINANCIAL IDENTITY THEFT $300 AND UNDER",
    "FINANCIAL ID THEFT:$300 &UNDER" : "FINANCIAL IDENTITY THEFT $300 AND UNDER",
    "CHILD ABDUCTION/STRANGER" : "CHILD ABDUCTION / STRANGER",
    "INDECENT SOLICITATION/CHILD" : "INDECENT SOLICITATION OF A CHILD",
    "CONTRIBUTE DELINQUENCY OF A CHILD" : "CONTRIBUTE TO THE DELINQUENCY OF CHILD",
    "INDECENT SOLICITATION/ADULT": "INDECENT SOLICITATION OF AN ADULT",
    "DELIVER CANNABIS TO PERSON <18": "DELIVER CANNABIS TO PERSON UNDER 18",
    'OTHER ARSON/EXPLOSIVE INCIDENT': 'OTHER ARSON / EXPLOSIVE INCIDENT',
    'SELL/GIVE/DEL LIQUOR TO MINOR': 'SELL / GIVE / DELIVER LIQUOR TO MINOR',
    'FINAN EXPLOIT-ELDERLY/DISABLED': 'FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON',
    'FALSE/STOLEN/ALTERED TRP': 'FALSE / STOLEN / ALTERED TRP',
    'RESIST/OBSTRUCT/DISARM OFFICER': 'RESIST / OBSTRUCT / DISARM OFFICER',
    "SOLICITING FOR BUSINESS" : "SOLICIT FOR BUSINESS",
    "SOLICIT NARCOTICS ON PUBLICWAY" : "SOLICIT NARCOTICS ON PUBLIC WAY",
    'VIO BAIL BOND: DOM VIOLENCE': 'VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE',
    'ALTER/FORGE PRESCRIPTION': 'ALTER / FORGE PRESCRIPTION',
    }
df['Description'] = df['Description'].apply(lambda x: replacements.get(x, x))
df.head()
# Out:
#          ID Case Number              Date                      Block IUCR  \
# 0   5741943    HN549294    8/25/2007 9:22         074XX N ROGERS AVE  560
# 1     25953    JE240540   5/24/2021 15:06        020XX N LARAMIE AVE  110
# 2     26038    JE279849    6/26/2021 9:24      062XX N MC CORMICK RD  110
# 3  13279676    JG507211  11-09-2023 07:30           019XX W BYRON ST  620
# 4  13274752    JG501049  11-12-2023 07:59  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                OTHER   False     False  2422        24  49.0
# 1               STREET    True     False  2515        25  36.0
# 2          PARKING LOT    True     False  1711        17  50.0
# 3            APARTMENT   False     False  1922        19  47.0
# 4   SMALL RETAIL STORE    True     False   632         6   6.0
#
#    Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 0             1.0      08A           NaN           NaN  2007
# 1            19.0      01A     1141387.0     1913179.0  2021
# 2            13.0      01A     1152781.0     1941458.0  2021
# 3             5.0        5     1162518.0     1925906.0  2023
# 4            44.0      08B     1183071.0     1847869.0  2023
#
#          Updated On   Latitude  Longitude                       Location
# 0   8/17/2015 15:03        NaN        NaN                            NaN
# 1  11/18/2023 15:39  41.917838 -87.755969  (41.917838056, -87.755968972)
# 2  11/18/2023 15:39  41.995219 -87.713355  (41.995219444, -87.713354912)
# 3  11/18/2023 15:39  41.952345 -87.677975  (41.952345086, -87.677975059)
# 4  12-09-2023 15:41  41.737751 -87.604856  (41.737750767, -87.604855911)

# %%
# To find unique values ​​of FBI code to check if any value should be changed
df['FBI Code'].unique()
# Out:
# array(['08A', '01A', '5', '08B', '6', '14', '11', '2', '10', '26', '7',
#        '3', '17', '15', '04B', '04A', '16', '9', '18', '20', '24', '13',
#        '12', '22', '19', '01B', '27'], dtype=object)

# %%
# To find unique values ​​of Domestic and Arrest to check if any value should be changed
print(df['Domestic'].unique())
print(df['Arrest'].unique())
# Out:
# [False  True]
# [False  True]

# %%
# To find unique values ​​of Location Description to check if any value should be changed
df['Location Description'].unique()
# Out:
# array(['OTHER', 'STREET', 'PARKING LOT', 'APARTMENT',
#        'SMALL RETAIL STORE', 'GAS STATION',
#        'PARKING LOT / GARAGE (NON RESIDENTIAL)', 'RESIDENCE - GARAGE',
#        'RESIDENCE - PORCH / HALLWAY', 'CURRENCY EXCHANGE', 'RESIDENCE',
#        'AUTO / BOAT / RV DEALERSHIP',
#        'POLICE FACILITY / VEHICLE PARKING LOT', 'DEPARTMENT STORE',
#        'CHA PARKING LOT / GROUNDS', 'RESTAURANT', 'GROCERY FOOD STORE',
#        'APPLIANCE STORE', 'CAR WASH', 'HOSPITAL BUILDING / GROUNDS',
#        'COMMERCIAL / BUSINESS OFFICE', 'SIDEWALK',
#        'DRIVEWAY - RESIDENTIAL', 'OTHER (SPECIFY)', 'PARK PROPERTY',
#        'ALLEY', 'BANK', 'DRUG STORE', 'VEHICLE NON-COMMERCIAL',
#        'RESIDENCE - YARD (FRONT / BACK)', 'BAR OR TAVERN',
#        'LAKEFRONT / WATERFRONT / RIVERBANK', 'SCHOOL - PUBLIC BUILDING',
#        'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA',
#        'NURSING / RETIREMENT HOME', 'HOTEL / MOTEL', 'CONVENIENCE STORE',
#        'CTA BUS STOP', 'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA',
#        'GOVERNMENT BUILDING / PROPERTY', 'TAVERN / LIQUOR STORE',
#        'CTA PLATFORM', 'COLLEGE / UNIVERSITY - RESIDENCE HALL',
#        'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA',
#        'VEHICLE - COMMERCIAL', 'SCHOOL - PUBLIC GROUNDS', 'WAREHOUSE',
#        'CTA TRAIN', nan, 'CTA BUS', 'ATM (AUTOMATIC TELLER MACHINE)',
#        'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA', 'CONSTRUCTION SITE',
#        'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA', 'ATHLETIC CLUB',
#        'CHURCH / SYNAGOGUE / PLACE OF WORSHIP', 'CTA STATION', 'CEMETARY',
#        'ABANDONED BUILDING', 'VACANT LOT / LAND',
#        'CHA HALLWAY / STAIRWELL / ELEVATOR', 'SCHOOL - PRIVATE GROUNDS',
#        'CHA APARTMENT', 'CTA TRACKS - RIGHT OF WAY',
#        'GAS STATION DRIVE/PROP.', 'BARBERSHOP', 'BOAT / WATERCRAFT',
#        'TAXICAB', 'ANIMAL HOSPITAL', 'SCHOOL - PRIVATE BUILDING',
#        'MEDICAL / DENTAL OFFICE', 'SPORTS ARENA / STADIUM',
#        'OTHER COMMERCIAL TRANSPORTATION', 'AIRPORT PARKING LOT',
#        'MOVIE HOUSE / THEATER',
#        'AIRPORT BUILDING NON-TERMINAL - SECURE AREA',
#        'CTA PARKING LOT / GARAGE / OTHER PROPERTY', 'DAY CARE CENTER',
#        'HIGHWAY / EXPRESSWAY', 'FACTORY / MANUFACTURING BUILDING',
#        'FEDERAL BUILDING', 'HOUSE', 'PAWN SHOP', 'CREDIT UNION',
#        'AIRCRAFT', 'FIRE STATION', 'COLLEGE / UNIVERSITY - GROUNDS',
#        'LIBRARY', 'VEHICLE - DELIVERY TRUCK', 'HALLWAY',
#        'VEHICLE - OTHER RIDE SHARE SERVICE (LYFT, UBER, ETC.)',
#        'OTHER RAILROAD PROPERTY / TRAIN DEPOT', 'AUTO',
#        'COIN OPERATED MACHINE', 'AIRPORT EXTERIOR - SECURE AREA',
#        'CLEANING STORE', 'AIRPORT TRANSPORTATION SYSTEM (ATS)',
#        'JAIL / LOCK-UP FACILITY', 'BRIDGE',
#        'AIRPORT EXTERIOR - NON-SECURE AREA',
#        'AIRPORT VENDING ESTABLISHMENT', 'AIRPORT/AIRCRAFT', 'GARAGE',
#        'KENNEL', 'YARD', 'FOREST PRESERVE', 'BOWLING ALLEY',
#        'VEHICLE - COMMERCIAL: ENTERTAINMENT / PARTY BUS', 'GANGWAY',
#        'AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA', 'RETAIL STORE',
#        'PORCH', 'DRIVEWAY', 'CHA PARKING LOT/GROUNDS', 'HOTEL',
#        'RESIDENCE-GARAGE', 'CHA HALLWAY',
#        'PARKING LOT/GARAGE(NON.RESID.)', 'VACANT LOT',
#        'VEHICLE - COMMERCIAL: TROLLEY BUS', 'TAVERN/LIQUOR STORE',
#        'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 'CTA SUBWAY STATION',
#        'RESIDENTIAL YARD (FRONT/BACK)', 'GOVERNMENT BUILDING/PROPERTY',
#        'SCHOOL, PUBLIC, BUILDING', 'STAIRWELL',
#        'POLICE FACILITY/VEH PARKING LOT', 'VEHICLE-COMMERCIAL',
#        'OTHER RAILROAD PROP / TRAIN DEPOT', 'SAVINGS AND LOAN', 'TAVERN',
#        'VESTIBULE', 'CTA "L" TRAIN', 'DUMPSTER', 'BASEMENT',
#        'CHA GROUNDS', 'MEDICAL/DENTAL OFFICE',
#        'NURSING HOME/RETIREMENT HOME', 'LIQUOR STORE',
#        'RESIDENCE PORCH/HALLWAY', 'BEACH', 'HOSPITAL', 'POOL ROOM',
#        'OFFICE', 'CHA LOBBY', 'SCHOOL YARD', 'SCHOOL, PRIVATE, GROUNDS',
#        'HOTEL/MOTEL', 'SCHOOL, PRIVATE, BUILDING',
#        'SCHOOL, PUBLIC, GROUNDS', 'HOSPITAL BUILDING/GROUNDS',
#        'CHA HALLWAY/STAIRWELL/ELEVATOR',
#        'COLLEGE/UNIVERSITY RESIDENCE HALL', 'SPORTS ARENA/STADIUM',
#        'GARAGE/AUTO REPAIR', 'NURSING HOME', 'COLLEGE/UNIVERSITY GROUNDS',
#        'DELIVERY TRUCK', 'VACANT LOT/LAND',
#        'FACTORY/MANUFACTURING BUILDING', 'ROOMING HOUSE', 'WOODED AREA',
#        'TRUCK', 'CHA PARKING LOT', 'MOVIE HOUSE/THEATER', 'CHA STAIRWELL',
#        'MOTEL', 'CLUB', 'PRAIRIE', 'YMCA', 'CTA PROPERTY',
#        'RAILROAD PROPERTY', 'EXPRESSWAY EMBANKMENT', 'LAKE',
#        'BARBER SHOP/BEAUTY SALON', 'BANQUET HALL', 'ELEVATOR',
#        'HIGHWAY/EXPRESSWAY', 'CHA ELEVATOR', 'RIVER BANK', 'COUNTY JAIL',
#        'CHURCH', 'NEWSSTAND', 'SEWER', 'CTA "L" PLATFORM', 'TAXI CAB',
#        'COACH HOUSE', 'LAGOON', 'TRUCKING TERMINAL', 'CHURCH PROPERTY',
#        'LAKEFRONT/WATERFRONT/RIVERBANK', 'ROOF', 'RIVER',
#        'GOVERNMENT BUILDING', 'POOLROOM', 'CHA BREEZEWAY',
#        'LIVERY STAND OFFICE', 'CHA PLAY LOT', 'BOAT/WATERCRAFT',
#        'CLEANERS/LAUNDROMAT', 'TRAILER', 'POLICE FACILITY',
#        'JUNK YARD/GARBAGE DUMP', 'PUBLIC GRAMMAR SCHOOL',
#        'FUNERAL PARLOR', 'LAUNDRY ROOM', 'PUBLIC HIGH SCHOOL',
#        'LIVERY AUTO', 'FACTORY', 'LOADING DOCK'], dtype=object)

# %%
# Modify the 'Location Description' column to update specific values for consistency
replace = {
    "MEDICAL/DENTAL OFFICE" : "MEDICAL / DENTAL OFFICE",
    "VEHICLE-COMMERCIAL" : "VEHICLE - COMMERCIAL",
    "POOLROOM" : "POOL ROOM",
    "TAXICAB" : "TAXI CAB" ,
    "BOAT/WATERCRAFT" : "BOAT / WATERCRAFT",
    "MOVIE HOUSE/THEATER" : "MOVIE HOUSE / THEATER",
    "LAKEFRONT/WATERFRONT/RIVERBANK" : "LAKEFRONT / WATERFRONT / RIVERBANK",
    "CHURCH/SYNAGOGUE/PLACE OF WORSHIP" : "CHURCH / SYNAGOGUE / PLACE OF WORSHIP",
    "PARKING LOT/GARAGE(NON.RESID.)" : "PARKING LOT / GARAGE (NON RESIDENTIAL)",
    "FACTORY/MANUFACTURING BUILDING" : "FACTORY / MANUFACTURING BUILDING",
    "COLLEGE/UNIVERSITY RESIDENCE HALL" : "COLLEGE / UNIVERSITY - RESIDENCE HALL",
    "COLLEGE/UNIVERSITY GROUNDS" : "COLLEGE / UNIVERSITY - GROUNDS",
    "HOTEL/MOTEL" : "HOTEL / MOTEL",
    "CHA PARKING LOT/GROUNDS" : "CHA PARKING LOT / GROUNDS",
    "GOVERNMENT BUILDING/PROPERTY" : "GOVERNMENT BUILDING / PROPERTY",
    "SCHOOL, PRIVATE, BUILDING": "SCHOOL - PRIVATE BUILDING",
    "SCHOOL, PUBLIC, BUILDING" : "SCHOOL - PUBLIC BUILDING",
    "SCHOOL, PRIVATE, GROUNDS" : "SCHOOL - PRIVATE GROUNDS",
    "SCHOOL, PUBLIC, GROUNDS" : "SCHOOL - PUBLIC GROUNDS",
    "HIGHWAY/EXPRESSWAY" : "HIGHWAY / EXPRESSWAY",
    "VACANT LOT/LAND" : "VACANT LOT / LAND",
    "POLICE FACILITY/VEH PARKING LOT" : "POLICE FACILITY / VEHICLE PARKING LOT",
    "NURSING HOME/RETIREMENT HOME" : "NURSING / RETIREMENT HOME",
    "CHA HALLWAY/STAIRWELL/ELEVATOR" : "CHA HALLWAY / STAIRWELL / ELEVATOR",
    "SPORTS ARENA/STADIUM" : "SPORTS ARENA / STADIUM",
    "RESIDENCE-GARAGE" : "RESIDENCE - GARAGE",
    "RESIDENCE PORCH/HALLWAY" : "RESIDENCE - PORCH / HALLWAY",
    "RESIDENTIAL YARD (FRONT/BACK)" : "RESIDENCE - YARD (FRONT / BACK)",
    "TAVERN/LIQUOR STORE" : "TAVERN / LIQUOR STORE",
    "OTHER RAILROAD PROP / TRAIN DEPOT" : "OTHER RAILROAD PROPERTY / TRAIN DEPOT"
}
df['Location Description'] = df['Location Description'].apply(lambda x: replace.get(x, x))

# %% [markdown]
# To check the unique values and null values after correcting spelling mistake, space mistake

# %%
for i in df.select_dtypes(include="object").columns:
    print(f"unique values of {i} = {df[i].nunique()}")
# Out:
# unique values of Case Number = 549434
# unique values of Date = 244168
# unique values of Block = 51020
# unique values of IUCR = 356
# unique values of Primary Type = 33
# unique values of Description = 338
# unique values of Location Description = 180
# unique values of FBI Code = 27
# unique values of Updated On = 2272
# unique values of Location = 278640

# %%
df.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      1673
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    336325
# Community Area          334906
# FBI Code                     0
# X Coordinate              6912
# Y Coordinate              6912
# Year                         0
# Updated On                   0
# Latitude                  6912
# Longitude                 6912
# Location                  6912
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  object
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
#  14  FBI Code              549999 non-null  object
#  15  X Coordinate          543087 non-null  float64
#  16  Y Coordinate          543087 non-null  float64
#  17  Year                  549999 non-null  int64
#  18  Updated On            549999 non-null  object
#  19  Latitude              543087 non-null  float64
#  20  Longitude             543087 non-null  float64
#  21  Location              543087 non-null  object
# dtypes: bool(2), float64(6), int64(4), object(10)
# memory usage: 85.0+ MB

# %%
df['Crime Date'] = pd.DatetimeIndex(df['Date']).day
df['Crime Month'] = pd.DatetimeIndex(df['Date']).month
df['Crime Year'] = pd.DatetimeIndex(df['Date']).year
df['Crime Time'] = pd.DatetimeIndex(df['Date']).time
df['Crime Week day'] = pd.DatetimeIndex(df['Date']).day_name()
df['Time of Day'] = df['Crime Time'].apply(lambda x: 'Morning' if x < pd.to_datetime('12:00:00').time() else 'Evening')

# %%
df.head()
# Out:
#          ID Case Number              Date                      Block IUCR  \
# 0   5741943    HN549294    8/25/2007 9:22         074XX N ROGERS AVE  560
# 1     25953    JE240540   5/24/2021 15:06        020XX N LARAMIE AVE  110
# 2     26038    JE279849    6/26/2021 9:24      062XX N MC CORMICK RD  110
# 3  13279676    JG507211  11-09-2023 07:30           019XX W BYRON ST  620
# 4  13274752    JG501049  11-12-2023 07:59  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                OTHER   False     False  2422        24  49.0
# 1               STREET    True     False  2515        25  36.0
# 2          PARKING LOT    True     False  1711        17  50.0
# 3            APARTMENT   False     False  1922        19  47.0
# 4   SMALL RETAIL STORE    True     False   632         6   6.0
#
#    Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 0             1.0      08A           NaN           NaN  2007
# 1            19.0      01A     1141387.0     1913179.0  2021
# 2            13.0      01A     1152781.0     1941458.0  2021
# 3             5.0        5     1162518.0     1925906.0  2023
# 4            44.0      08B     1183071.0     1847869.0  2023
#
#          Updated On   Latitude  Longitude                       Location  \
# 0   8/17/2015 15:03        NaN        NaN                            NaN
# 1  11/18/2023 15:39  41.917838 -87.755969  (41.917838056, -87.755968972)
# 2  11/18/2023 15:39  41.995219 -87.713355  (41.995219444, -87.713354912)
# 3  11/18/2023 15:39  41.952345 -87.677975  (41.952345086, -87.677975059)
# 4  12-09-2023 15:41  41.737751 -87.604856  (41.737750767, -87.604855911)
#
#    Crime Date  Crime Month  Crime Year Crime Time Crime Week day Time of Day
# 0          25            8        2007   09:22:00       Saturday     Morning
# 1          24            5        2021   15:06:00         Monday     Evening
# 2          26            6        2021   09:24:00       Saturday     Morning
# 3           9           11        2023   07:30:00       Thursday     Morning
# 4          12           11        2023   07:59:00         Sunday     Morning

# %%
df.columns

# %% [markdown]
# Fill Missing values

# %%
# 'Location Description' has missing (empty) values. 
# As the exact location for these entries is unavailable, 
# the missing values have been filled with 'UNKNOWN' to ensure consistency in the dataset.
df['Location Description'] = df['Location Description'].fillna('UNKNOWN')

# %%
df.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description         0
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                         0
# Community Area          334906
# FBI Code                     0
# X Coordinate              6912
# Y Coordinate              6912
# Year                         0
# Updated On                   0
# Latitude                  6912
# Longitude                 6912
# Location                  6912
# Crime Date                   0
# Crime Month                  0
# Crime Year                   0
# Crime Time                   0
# Crime Week day               0
# Time of Day                  0
# dtype: int64

# %%
# Group by relevant features and fill missing 'Ward' with the mode of each group
grouped_mode = df.groupby(['District', 'Primary Type'])['Ward'].apply(lambda x: x.mode()[0] if not x.mode().empty else pd.NA)

# Use the mode to fill missing values
df['Ward'] = df.apply(
    lambda row: grouped_mode.loc[(row['District'], row['Primary Type'])] 
    if pd.isna(row['Ward']) else row['Ward'], axis=1
)

# Group by relevant features and fill missing 'Ward' with the mode of each group
grouped_mode = df.groupby(['District'])['Ward'].apply(lambda x: x.mode()[0] if not x.mode().empty else pd.NA)

# Use the mode to fill missing values
df['Ward'] = df.apply(
    lambda row: grouped_mode.loc[(row['District'])] 
    if pd.isna(row['Ward']) else row['Ward'], axis=1
)

# %%
# Group by relevant features and fill missing 'ommunity' with the mode of each group
grouped_mode = df.groupby(['District', 'Primary Type'])['Community Area'].apply(lambda x: x.mode()[0] if not x.mode().empty else pd.NA)

# Use the mode to fill missing values
df['Community Area'] = df.apply(
    lambda row: grouped_mode.loc[(row['District'], row['Primary Type'])] 
    if pd.isna(row['Community Area']) else row['Community Area'], axis=1
)

# Group by relevant features and fill missing 'Community' with the mode of each group
grouped_mode = df.groupby(['District'])['Community Area'].apply(lambda x: x.mode()[0] if not x.mode().empty else pd.NA)

# Use the mode to fill missing values
df['Community Area'] = df.apply(
    lambda row: grouped_mode.loc[(row['District'])] 
    if pd.isna(row['Community Area']) else row['Community Area'], axis=1
)

# %%
df.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       0
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       0
# Community Area             0
# FBI Code                   0
# X Coordinate            6912
# Y Coordinate            6912
# Year                       0
# Updated On                 0
# Latitude                6912
# Longitude               6912
# Location                6912
# Crime Date                 0
# Crime Month                0
# Crime Year                 0
# Crime Time                 0
# Crime Week day             0
# Time of Day                0
# dtype: int64

# %%
new_backup = df.copy()

# %%
lat_median = df.groupby(['District', 'Block'])['Latitude'].transform('median')
df['Latitude'] = df['Latitude'].fillna(lat_median)

lat_median_2 = df.groupby(['District'])['Latitude'].transform('median')
df['Latitude'] = df['Latitude'].fillna(lat_median_2)

# %%
long_median = df.groupby(['District', 'Block'])['Longitude'].transform('median')
df['Longitude'] = df['Longitude'].fillna(long_median)

long_median_2 = df.groupby(['District'])['Latitude'].transform('median')
df['Longitude'] = df['Longitude'].fillna(long_median_2)

# %%
x_median = df.groupby(['District', 'Block'])['X Coordinate'].transform('median')
df['X Coordinate'] = df['X Coordinate'].fillna(x_median)

x_median_2 = df.groupby(['District'])['Latitude'].transform('median')
df['X Coordinate'] = df['X Coordinate'].fillna(x_median_2)

# %%
y_median = df.groupby(['District', 'Block'])['Y Coordinate'].transform('median')
df['Y Coordinate'] = df['Y Coordinate'].fillna(y_median)

y_median_2 = df.groupby(['District'])['Latitude'].transform('median')
df['Y Coordinate'] = df['Y Coordinate'].fillna(y_median_2)

# %%
df.drop(columns=['Location'], axis=1, inplace=True)

# %%
df.drop(columns=['Year'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Updated On              0
# Latitude                0
# Longitude               0
# Crime Date              0
# Crime Month             0
# Crime Year              0
# Crime Time              0
# Crime Week day          0
# Time of Day             0
# dtype: int64

# %%
df.head()
# Out:
#          ID Case Number              Date                      Block IUCR  \
# 0   5741943    HN549294    8/25/2007 9:22         074XX N ROGERS AVE  560
# 1     25953    JE240540   5/24/2021 15:06        020XX N LARAMIE AVE  110
# 2     26038    JE279849    6/26/2021 9:24      062XX N MC CORMICK RD  110
# 3  13279676    JG507211  11-09-2023 07:30           019XX W BYRON ST  620
# 4  13274752    JG501049  11-12-2023 07:59  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                OTHER   False     False  2422        24  49.0
# 1               STREET    True     False  2515        25  36.0
# 2          PARKING LOT    True     False  1711        17  50.0
# 3            APARTMENT   False     False  1922        19  47.0
# 4   SMALL RETAIL STORE    True     False   632         6   6.0
#
#    Community Area FBI Code  X Coordinate  Y Coordinate        Updated On  \
# 0             1.0      08A     1163633.0     1949479.0   8/17/2015 15:03
# 1            19.0      01A     1141387.0     1913179.0  11/18/2023 15:39
# 2            13.0      01A     1152781.0     1941458.0  11/18/2023 15:39
# 3             5.0        5     1162518.0     1925906.0  11/18/2023 15:39
# 4            44.0      08B     1183071.0     1847869.0  12-09-2023 15:41
#
#     Latitude  Longitude  Crime Date  Crime Month  Crime Year Crime Time  \
# 0  42.017007 -87.673208          25            8        2007   09:22:00
# 1  41.917838 -87.755969          24            5        2021   15:06:00
# 2  41.995219 -87.713355          26            6        2021   09:24:00
# 3  41.952345 -87.677975           9           11        2023   07:30:00
# 4  41.737751 -87.604856          12           11        2023   07:59:00
#
#   Crime Week day Time of Day
# 0       Saturday     Morning
# 1         Monday     Evening
# 2       Saturday     Morning
# 3       Thursday     Morning
# 4         Sunday     Morning

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Updated On', 'Latitude', 'Longitude', 'Crime Date',
#        'Crime Month', 'Crime Year', 'Crime Time', 'Crime Week day',
#        'Time of Day'],
#       dtype='object')

# %%
df.columns = ['ID', 'CaseNumber', 'Date', 'Block', 'IUCR', 'PrimaryType', 'Decription', 'LocationDescription', 
                    'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'CommunityArea', 'FBICode', 'XCoordinate', 
                    'YCcoordinate', 'UpdatedOn','Latitide','Logtitude','CrimeDate', 'CrimeMonth', 'CrimeYear',
                    'CrimeTime', 'CrimeWeekDay', 'TimeOfDay']

# %%
df.to_csv('cleaned_chicago_crime_df.csv', index=False)

# %%
cleaned_file = path + '\\cleaned_chicago_crime_df.csv'
final_df = pd.read_csv(cleaned_file)

# %%
final_df.head(2)
# Out:
#         ID CaseNumber             Date                Block IUCR PrimaryType  \
# 0  5741943   HN549294   8/25/2007 9:22   074XX N ROGERS AVE  560     ASSAULT
# 1    25953   JE240540  5/24/2021 15:06  020XX N LARAMIE AVE  110    HOMICIDE
#
#             Decription LocationDescription  Arrest  Domestic  ...  \
# 0               SIMPLE               OTHER   False     False  ...
# 1  FIRST DEGREE MURDER              STREET    True     False  ...
#
#    YCcoordinate         UpdatedOn   Latitide  Logtitude CrimeDate  CrimeMonth  \
# 0     1949479.0   8/17/2015 15:03  42.017007 -87.673208        25           8
# 1     1913179.0  11/18/2023 15:39  41.917838 -87.755969        24           5
#
#    CrimeYear CrimeTime  CrimeWeekDay  TimeOfDay
# 0       2007  09:22:00      Saturday    Morning
# 1       2021  15:06:00        Monday    Evening
#
# [2 rows x 26 columns]

# %%
# Library
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# Define the database connection parameters
db_params = {
	'host': 'localhost',
	'database': 'postgres',
	'user': 'postgres',
	'password': 'highre123'
}

# %%
conn = psycopg2.connect(
	host=db_params['host'],
	database=db_params['database'],
	user=db_params['user'],
	password=db_params['password']
)
cur = conn.cursor()
conn.set_session(autocommit=True)

# %%
engine = create_engine(f'postgresql://{db_params["user"]}:{db_params["password"]}@{db_params["host"]}/{db_params["database"]}')

# %%
final_df.to_sql('chicago_crime',engine, if_exists='replace', index=False)
# Out:
# 999
